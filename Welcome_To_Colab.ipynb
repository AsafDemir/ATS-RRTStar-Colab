# %% [markdown]
# <a href="https://colab.research.google.com/github/AsafDemir/ATS-RRTStar-Colab/blob/main/Welcome_To_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !g++ main.cpp -o main
# Out:
# main.cpp:29:31: error: ‘FALSE’ was not declared in this scope
#    29 |     bool FOUND_INITIAL_PATH = FALSE;
#       |                               ^~~~~
# main.cpp:31:25: error: ‘FALSE’ was not declared in this scope
#    31 |     bool IS_NEAR_GOAL = FALSE;
#       |                         ^~~~~
# main.cpp: In member function ‘void ChoosePath::evaluateNewNode(const std::vector<Node>&, int, const State&, int, const CollisionChecker&)’:
# main.cpp:385:40: error: assignment of member ‘Node::parent’ in read-only object
#   385 |             tree[goalNodeIndex].parent = newNodeIndex;
# main.cpp:386:38: error: assignment of member ‘Node::cost’ in read-only object
#   386 |             tree[goalNodeIndex].cost = newNode.cost + computeDistance(newNode.state, goal);
# main.cpp:408:17: error: ‘FOUND_INITIAL_PATH’ was not declared in this scope; did you mean ‘RRTConfig::FOUND_INITIAL_PATH’?
#   408 |             if (FOUND_INITIAL_PATH == FALSE){ FOUND_INITIAL_PATH = TRUE; }
# ...
